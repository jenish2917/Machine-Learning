# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
x, y = make_classification(n_features = 5, n_redundant= 0, n_informative= 5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(x, columns=['col1', 'col2', 'col3', 'col4', 'col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.025600 -1.016439 -2.698648 -1.181161 -3.014974       0
# 1 -1.043834 -2.577967  1.061619  1.580707  1.386050       1
# 2  0.859030 -1.682001 -0.657963  2.696089  1.184726       1
# 3 -0.691576  2.474298  0.008462 -1.648086  0.689743       0
# 4 -2.318594 -1.240312 -0.097896  0.675166  0.166373       1

# %%
# Function for row sampling

def sample_rows(df, percent):
    return df.sample(int(percent*df.shape[0]), replace=True)

# %%
#Function for feature sampling
def sample_fearures(df, percent):
    cols = random.sample(df.columns.tolist()[:-1], int(percent*df.shape[1]))
    return df[cols]

# %%
# Function for combined sampling

def combined_sampling(df, row_percent, col_percent):
    new_df = sample_rows(df, row_percent)
    return sample_fearures(new_df,col_percent)

# %%
df1 = sample_rows(df, 0.2)

# %%
df2 = sample_rows(df, 0.2)

# %%
df3 = sample_rows(df, 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,:-1], df1.target)
clf2.fit(df2.iloc[:,:-1], df2.target)
clf3.fit(df3.iloc[:,:-1], df3.target)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[1] <= -0.442\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.25, 0.5, 'x[0] <= -0.038\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.5, 'x[3] <= 0.359\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.2857142857142857, 0.9, 'x[1] <= -1.081\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.14285714285714285, 0.7, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.21428571428571427, 0.8, 'True  '),
#  Text(0.42857142857142855, 0.7, 'x[0] <= -3.384\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.3571428571428571, 0.8, '  False'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5714285714285714, 0.5, 'x[3] <= 0.158\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7142857142857143, 0.3, 'x[3] <= 0.668\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[1] <= 1.018\ngini = 0.42\nsamples = 20\nvalue = [6, 14]'),
#  Text(0.4, 0.5, 'x[4] <= -2.658\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
clf1.predict(np.array([-1.894966,	-1.263395,	-1.381595,	1.621081,	-1.136317]).reshape(1,5))
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([-1.894966,	-1.263395,	-1.381595,	1.621081,	-1.136317]).reshape(1,5))
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([-1.894966,	-1.263395,	-1.381595,	1.621081,	-1.136317]).reshape(1,5))
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)
x, y = make_circles(n_samples=500, noise=0.35, factor=0.1, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x.shape, y.shape
# Out:
# ((500, 2), (500,))

# %%
plt.scatter(x[:,0], x[:,1], c=y)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(random_state=42)
dtree.fit(x_train, y_train)

plt.figure(figsize=(12, 8))
x_range = np.linspace(x.min(), x.max(), 100)
xx1, xx2 = np.meshgrid(x_range, x_range)
y_hat = dtree.predict(np.c_[xx1.ravel(), xx2.ravel()])
y_hat = y_hat.reshape(xx1.shape)
plt.contourf(xx1, xx2, y_hat, alpha=0.2)
plt.scatter(x[:,0], x[:,1], c=y, alpha=0.7)
plt.title('Decision Tree')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=500, random_state=42)
rf.fit(x_train, y_train)

plt.figure(figsize=(12, 8))
x_range = np.linspace(x[:, 0].min(), x[:, 0].max(), 100)
xx1, xx2 = np.meshgrid(x_range, x_range)
y_hat = rf.predict(np.c_[xx1.ravel(), xx2.ravel()])
y_hat = y_hat.reshape(xx1.shape)
plt.contourf(xx1, xx2, y_hat, alpha=0.2)
plt.scatter(x[:, 0], x[:, 1], c=y, cmap='viridis', alpha=0.7)
plt.title('Random Forest')
plt.show()

# %%
n_train = 100
n_test = 1000
noise = 0.1

def f(x):
    x = x.ravel()
    return np.exp(-x ** 2) + 1.5 * np.exp(-(x - 2) ** 2)

def generate(n_samples, noise):
    x = np.random.rand(n_samples) * 10 - 5
    x = np.sort(x).ravel()
    y = np.exp(-x ** 2) + 1.5 * np.exp(-(x - 2) ** 2)\
        + np.random.normal(0.0, noise, n_samples)
    x = x.reshape((n_samples, 1))

    return x, y

x_train, y_train = generate(n_samples=n_train, noise=noise)
x_test, y_test = generate(n_samples=n_test, noise=noise)

# %%
plt.figure(figsize=(18, 8))
plt.plot(x_test, f(x_test), "r")
plt.scatter(x_train, y_train, s=20)
plt.xlim([-5, 5])
# Out:
# (-5.0, 5.0)

# %%
# Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor

dtree = DecisionTreeRegressor().fit(x_train, y_train)
d_predict = dtree.predict(x_test)

plt.figure(figsize=(18, 8))
plt.plot(x_test, f(x_test), "r")
plt.scatter(x_train, y_train, s=20, c="b")
plt.plot(x_test, d_predict, "g", lw=2)
plt.xlim([-5, 5])
plt.title("Decision Tree, MSE = %.2f" % np.sum((y_test - d_predict) ** 2))
# Out:
# Text(0.5, 1.0, 'Decision Tree, MSE = 21.97')

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=1000).fit(x_train, y_train)
rf_predict = rf.predict(x_test)

plt.figure(figsize=(18, 8))
plt.plot(x_test, f(x_test), "r")
plt.scatter(x_train, y_train, s=20, c="b")
plt.plot(x_test, rf_predict, "g", lw=2)
plt.xlim([-5, 5])
plt.title("Random Forest, MSE = %.2f" % np.sum((y_test - rf_predict) ** 2))
# Out:
# Text(0.5, 1.0, 'Random Forest, MSE = 16.87')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
x = df.drop('target', axis=1)
y = df['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (242, 13) (61, 13)

# %%
rf = RandomForestClassifier()
gb = GradientBoostingClassifier()
svc = SVC()
lr = LogisticRegression()

# %%
rf.fit(x_train, y_train)
Y_pred_rf = rf.predict(x_test)
acc_rf = round(accuracy_score(y_test, Y_pred_rf) * 100, 2)
acc_rf
# Out:
# 83.61

# %%
gb.fit(x_train, y_train)
Y_pred_gb = gb.predict(x_test)
acc_gb = round(accuracy_score(y_test, Y_pred_gb) * 100, 2)
acc_gb
# Out:
# 77.05

# %%
svc.fit(x_train, y_train)
Y_pred_svc = svc.predict(x_test)
acc_svc = round(accuracy_score(y_test, Y_pred_svc) * 100, 2)
acc_svc
# Out:
# 70.49

# %%
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
acc_lr = round(accuracy_score(y_test, y_pred) * 100, 2)
acc_lr
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 88.52

# %%
rf = RandomForestClassifier(max_samples= 0.75, random_state=42)
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9016393442622951

# %%
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(RandomForestClassifier(max_samples= 0.75, random_state=42), x, y, cv=10, scoring='accuracy'))
# Out:
# 0.8349462365591398

# %% [markdown]
# GridSearchCV

# %%
n_estimetors = [1, 2, 4, 8, 16, 32, 64, 100, 200]
max_samples = [0.1, 0.5, 0.75, 1.0]
max_features = [0.2, 0.5, 0.75, 1.0]
max_depth = [1, 2, 4, 8, 16, 32, 64, 100, 200, None]

# %%
param_grid = {
    'n_estimators': n_estimetors,
    'max_samples': max_samples,
    'max_features': max_features,
    'max_depth': max_depth
}
print(param_grid)
# Out:
# {'n_estimators': [1, 2, 4, 8, 16, 32, 64, 100, 200], 'max_samples': [0.1, 0.5, 0.75, 1.0], 'max_features': [0.2, 0.5, 0.75, 1.0], 'max_depth': [1, 2, 4, 8, 16, 32, 64, 100, 200, None]}

# %%
rf = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV

rf_grid = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, verbose=2, n_jobs=-1)

# %%
rf_grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1440 candidates, totalling 7200 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 4, 8, 16, 32, 64, 100, 200, None],
#                          'max_features': [0.2, 0.5, 0.75, 1.0],
#                          'max_samples': [0.1, 0.5, 0.75, 1.0],
#                          'n_estimators': [1, 2, 4, 8, 16, 32, 64, 100, 200]},
#              verbose=2)

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 1, 'max_features': 0.2, 'max_samples': 0.75, 'n_estimators': 32}

# %%
rf_grid.best_score_
# Out:
# 0.8511054421768707

# %% [markdown]
# RandomSearchCV

# %%
n_estimetors = [1, 2, 4, 8, 16, 32, 64, 100, 200]
max_samples = [0.1, 0.5, 0.75, 1.0]
max_features = [0.2, 0.5, 0.75, 1.0]
max_depth = [1, 2, 4, 8, 16, 32, 64, 100, 200, None]
bootstarap = [True, False]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

# %%
param_grid = {
    'n_estimators': n_estimetors,
    'max_samples': max_samples,
    'max_features': max_features,
    'max_depth': max_depth,
    'bootstrap': bootstarap,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf
}

# %%
from sklearn.model_selection import RandomizedSearchCV

rf_grid = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, n_iter=100, cv=5, verbose=2, n_jobs=-1)

# %%
rf_grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 240 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
# ...

# %%
rf_grid.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 10,
#  'min_samples_leaf': 4,
#  'max_samples': 0.1,
#  'max_features': 0.2,
#  'max_depth': 8,
#  'bootstrap': True}

# %%
rf_grid.best_score_
# Out:
# 0.8386904761904763

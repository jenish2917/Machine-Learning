# %% [markdown]
# Logistic Regression

# %% [markdown]
# applicable when we classifiy of saprate two class by line for 2d ond hyperplan for n dimension data

# %%
from sklearn.datasets import make_classification
import numpy as np
x, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1,random_state=41, hypercube=False, class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s = 100)

# %%
def perceptron(x,y):
    x = np.insert(x, 0, 1, axis=1)
    weights = np.ones(x.shape[1])
    lr = 0.1

    for i in range(100):
        j = np.random.randint(0, 100)
        y_hat = step(np.dot(x[j], weights))
        weights += lr * (y[j] - y_hat) * x[j]
    
    return weights[0], weights[1:]

def step(z):
    return 1/(1+np.exp(-z))

# %%
intercept_, coef_ = perceptron(x, y)

# %%
print(intercept_, coef_)
# Out:
# 1.0243371990009906 [2.3299415  0.20259448]

# %%
m = -coef_[0] / coef_[1]
b = -intercept_ / coef_[1]

# %%
x_input = np.linspace(-3, 3, 100)
y_output = m * x_input + b

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_input, y_output, 'r', linewidth=3)
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s = 100)
plt.ylim(-3, 2)
# Out:
# (-3.0, 2.0)

# %%
def perception(x,y):
    m= []
    b= []

    x = np.insert(x, 0, 1, axis=1)
    weights = np.ones(x.shape[1])
    lr = 0.1

    for i in range(200):
        j = np.random.randint(0, 100)
        y_hat = step(np.dot(x[j], weights))
        weights += lr * (y[j] - y_hat) * x[j]

        m.append(-weights[1] / weights[2])
        b.append(-weights[0] / weights[2])
    
    return m, b

# %%
m, b = perception(x, y)

# %%
# %matplotlib notebook
import matplotlib.animation as FuncAnimation
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots(figsize=(10, 6))
x_i = np.arange(-3, 3, 0.1)
y_i = m[0] * x_i + b[0]

ax.scatter(x[:,0], x[:,1], c=y, cmap='winter', s = 100)
line, = ax.plot(x_i, x_i*m[0] + b[0], 'r-', linewidth=3)
plt.ylim(-3, 3)
def update(i):
    label = 'ephoch {}'.format(i + 1)
    line.set_ydata(x_i * m[i] + b[i])
    ax.set_xlabel(label)
# Out:
# <div id='80001cb6-a9bf-4311-a878-581b505f8ecf'></div>

# %%
from sklearn.datasets import make_classification
import numpy as np
x, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1,random_state=41, hypercube=False, class_sep=30)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s = 100)
plt.ylim(-3, 3)
plt.show()
# Out:
# <div id='8c9df778-24e4-4da9-9ac2-ee1eedbf680a'></div>

# %%
from sklearn.datasets import make_classification
import numpy as np
x, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, n_clusters_per_class=1,random_state=41, hypercube=False, class_sep=30)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s = 100)
# Out:
# <div id='7219fc7d-4f11-45f0-8d2d-f518d0003f60'></div>

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression(penalty = None, solver= 'sag')
lor.fit(x, y)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(penalty=None, solver='sag')

# %%
print(lor.intercept_, lor.coef_)
# Out:
# [4.1915353] [[3.89852346 0.16968369]]

# %%
m1 = -lor.coef_[0, 0] / lor.coef_[0, 1]
b1 = -lor.intercept_ / lor.coef_[0, 1]

# %%
x_input = np.linspace(-3, 3, 100)
y_output = m1 * x_input + b1

# %%
def gd(x, y):
    x = np.insert(x, 0, 1, axis=1)
    weights = np.ones(x.shape[1])
    lr = 0.5

    for i in range(500):
        y_hat = sigmoid(np.dot(x, weights))
        weights += lr * (np.dot((y - y_hat),x)/x.shape[0])

    return weights[1:], weights[0]

def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
coef_, intercept_ = gd(x, y)

# %%
m = -coef_[0] / coef_[1]
b = -intercept_ / coef_[1]

# %%
x_input1 = np.linspace(-3, 3, 100)
y_output1 = m * x_input1 + b

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_input, y_output, 'r', linewidth=3)
plt.plot(x_input1, y_output1, 'g', linewidth=3)
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s = 100)
plt.ylim(-3, 3)
# Out:
# <div id='29e6d96e-c5fe-452d-a03b-0373ac8239a2'></div>
# (-3.0, 3.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# %%
def analyzer(max_depth):
    data = pd.read_csv('Social_Network_Ads.csv')
    x = data.iloc[:, [2, 3]].values
    y = data.iloc[:, 4].values

    clf = DecisionTreeClassifier(max_depth=max_depth)
    clf.fit(x, y)

    a = np.arange(start = x[:, 0].min() - 1, stop = x[:, 0].max() + 1, step = 0.1)
    b = np.arange(start = x[:, 1].min() - 1, stop = x[:, 1].max() + 1, step = 100)

    xx, yy = np.meshgrid(a, b)

    input_array = np.array([xx.ravel(), yy.ravel()]).T

    labels = clf.predict(input_array)

    plt.contourf(xx, yy, labels.reshape(xx.shape), alpha = 0.5)
    plt.scatter(x[:,0], x[:,1], c = y)

# %%
analyzer(max_depth=None)

# %%
analyzer(max_depth=1)

# %%
analyzer(max_depth=2)

# %%
analyzer(max_depth=3)

# %%
analyzer(max_depth=4)

# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (2.2.2)
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (3.9.2)
# Requirement already satisfied: colour in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from dtreeviz) (8.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
import graphviz.backend as be

# %%
clas = tree.DecisionTreeClassifier(max_depth=3)
iris = load_iris()

x_train = iris.data
y_train = iris.target
clas.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.375, 0.875, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.125, 0.125, 'gini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.375, 0.125, 'gini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.625, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# 1. Classification

# %%
from dtreeviz import dtreeviz

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from dtreeviz import dtreeviz

# Load data
iris = load_iris()
x_train = iris.data
y_train = iris.target

# Train the model
clas = DecisionTreeClassifier()
clas.fit(x_train, y_train)

# Visualize the decision tree
viz = dtreeviz(clas, 
               x_train, 
               y_train, 
               target_name='species', 
               feature_names=iris.feature_names, 
               class_names=['setosa', 'versicolor', 'virginica'])

viz.view()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6428\3479478155.py:15: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 15
#      12 clas.fit(x_train, y_train)
#      14 # Visualize the decision tree
# ---> 15 viz = dtreeviz(clas,
#      16                x_train,
#      17                y_train,
#      18                target_name='species',
#      19                feature_names=iris.feature_names,
#      20                class_names=['setosa', 'versicolor', 'virginica'])
#      22 viz.view()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtreeviz\compatibility.py:254, in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     251 shadow_tree = ShadowDecTree.get_shadow_tree(tree_model, X_train, y_train, feature_names, target_name, class_names,
#     252                                             tree_index)
#     253 model = DTreeVizAPI(shadow_tree)
# --> 254 return model.view(precision, orientation,
#     255                   instance_orientation,
#     256                   show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X,
#     257                   max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize,
#     258                   fontname, title, title_fontsize, colors=colors, scale=scale)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtreeviz\trees.py:523, in DTreeVizAPI.view(self, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, leaftype, highlight_path, x, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     521 tmp = tempfile.gettempdir()
#     522 if x is not None:
# --> 523     path = self.shadow_tree.predict_path(x)
#     524     highlight_path = [n.id for n in path]
#     526 color_values = colors['classes'][n_classes]
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:340, in ShadowDecTree.predict_path(self, x)
#     337     return walk(t.right, x, path)
#     339 path = []
# --> 340 walk(self.root, x, path)
#     341 return path
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtreeviz\models\shadow_decision_tree.py:335, in ShadowDecTree.predict_path.<locals>.walk(t, x, path)
#     333 if t.isleaf():
#     334     return None
# --> 335 if self.shouldGoLeftAtSplit(t.id, x[t.feature()]):
#     336     return walk(t.left, x, path)
#     337 return walk(t.right, x, path)
#
# TypeError: 'int' object is not subscriptable

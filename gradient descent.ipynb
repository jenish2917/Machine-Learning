# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x, y = make_regression(n_samples=4, n_features=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x)
lr.coef_, lr.intercept_
# Out:
# (array([78.35063668]), 26.15963284313262)

# %%
plt.scatter(x, y)
plt.plot(x, lr.predict(x), color='red')

# %%
#Let's apply Gradient Descent assuming slop is constant m = 78.35
# let's assume intercept is constant b = 0.0
y_pred = ((78.35 * x) + 0.0).reshape(4)

# %%
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.plot(x, lr.predict(x), color='green')
plt.legend()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2992\892189687.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
m = 78.35
b = 0.0

loss_slope = -2 * np.sum(y - (m * x.ravel() + b))
loss_slope
# Out:
# -209.27763408209216

# %%
ler = 0.1
b = b - ler * loss_slope
b
# Out:
# 20.927763408209216

# %%
y_pred1 = ((78.35 * x) + b).reshape(4)

plt.scatter(x, y)
plt.plot(x, y_pred, color='blue')
plt.plot(x, y_pred1, color='red')
plt.plot(x, lr.predict(x), color='black')
plt.legend()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2992\2306315053.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#iteration 2
loss_slope = -2 * np.sum(y - (m * x.ravel() + b))
loss_slope
# Out:
# -41.85552681641843

# %%
b = b - ler * loss_slope
b
# Out:
# 25.11331608985106

# %%
y_pred2 = ((78.35 * x) + b).reshape(4)

plt.scatter(x, y)
plt.plot(x, y_pred, color='blue')
plt.plot(x, y_pred1, color='red')
plt.plot(x, y_pred2, color='green')
plt.plot(x, lr.predict(x), color='black')
plt.legend()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2992\2444696544.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#iteration 3
loss_slope = -2 * np.sum(y - (m * x.ravel() + b))
loss_slope
# Out:
# -8.37110536328369

# %%
b = b - ler * loss_slope
b
# Out:
# 25.95042662617943

# %%
y_pred3 = ((78.35 * x) + b).reshape(4)

plt.scatter(x, y)
plt.plot(x, y_pred, color='blue')
plt.plot(x, y_pred1, color='red')
plt.plot(x, y_pred2, color='green')
plt.plot(x, y_pred3, color='yellow')
plt.plot(x, lr.predict(x), color='black')
plt.legend()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2992\712060181.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#iteration 4
loss_slope = -2 * np.sum(y - (m * x.ravel() + b))
loss_slope
# Out:
# -1.6742210726567492

# %%
b = b - ler * loss_slope
b
# Out:
# 26.117848733445104

# %%
y_pred4 = ((78.35 * x) + b).reshape(4)

plt.scatter(x, y)
plt.plot(x, y_pred, color='blue')
plt.plot(x, y_pred1, color='red')
plt.plot(x, y_pred2, color='green')
plt.plot(x, y_pred3, color='yellow')
plt.plot(x, y_pred4, color='purple')
plt.plot(x, lr.predict(x), color='black')
plt.legend()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2992\3512278540.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#iteration 5
loss_slope = -2 * np.sum(y - (m * x.ravel() + b))
print(loss_slope)

b = b - ler * loss_slope
print(b)

y_pred5 = ((78.35 * x) + b).reshape(4)

plt.scatter(x, y)
plt.plot(x, y_pred, color='blue')
plt.plot(x, y_pred1, color='red')
plt.plot(x, y_pred2, color='green')
plt.plot(x, y_pred3, color='yellow')
plt.plot(x, y_pred4, color='purple')
plt.plot(x, y_pred5, color='pink')
plt.plot(x, lr.predict(x), color='black')
plt.legend()
plt.show()
# Out:
# -0.33484421453131574
# 26.151333154898236
# C:\Users\admin\AppData\Local\Temp\ipykernel_2992\2642099173.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
b = -100
m = 78.35
ler = 0.01

epochs = 100

for i in range(epochs):
    loss_slope = -2 * np.sum(y - (m * x.ravel() + b))
    b = b - ler * loss_slope

    y_pred = m * x + b

    plt.plot(x, y_pred)

plt.scatter(x, y)

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score

# %%
x, y = make_regression(n_samples=100, n_features=1, n_targets=1, noise=20, random_state=13)

# %%
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x, y)
print(lr.coef_, lr.intercept_)
# Out:
# [27.82809103] -2.29474455867698

# %%
np.mean(cross_val_score(lr, x, y, cv=10, scoring='r2'))
# Out:
# 0.6375011587464419

# %%
lr.coef_, lr.intercept_
# Out:
# (array([27.82809103]), -2.29474455867698)

# %%
class GDRegressor:
    def __init__(self, learning_rate, epochs):
        self.m = 100
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, x, y):
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - (self.m * x.ravel() + self.b))
            loss_slope_m = -2 * np.sum(x.ravel() * (y - (self.m * x.ravel() + self.b)))
            self.m = (self.m - self.lr * loss_slope_m)
            self.b = (self.b - self.lr * loss_slope_b)
        print(self.m, self.b)

    def predict(self, x):
        return self.m * x + self.b

# %%
gd = GDRegressor(0.001, 100)

# %%
gd.fit(x, y)
# Out:
# 27.828091872608653 -2.2947448944994893

# %%
gd.predict(x)
# Out:
# array([[-22.11921769],
#        [-14.45967436],
#        [-14.92180785],
#        [ 24.22071289],
#        [  4.32438488],
#        [ 21.67112435],
#        [ -9.06605019],
#        [  2.851948  ],
#        [-22.35879005],
#        [-14.25796038],
#        [ 53.78500537],
#        [  8.75972323],
#        [  3.48793408],
#        [ -8.76271341],
#        [-23.68416824],
#        [ 10.31579463],
#        [ 15.5120051 ],
#        [  7.71035286],
#        [-47.24011768],
#        [ 46.38331635],
#        [-24.25080397],
#        [-16.54175657],
#        [-28.12854285],
#        [ 57.54630988],
#        [ -8.06489135],
#        [-47.90758693],
#        [-11.71784478],
#        [-11.25883162],
#        [-15.69039288],
#        [-16.85340673],
#        [ 17.79616505],
#        [ 19.01909815],
#        [ 10.32476716],
#        [-37.40283105],
#        [-63.15798965],
#        [-35.28268842],
#        [  3.75651986],
#        [ 34.72543668],
#        [-32.54893408],
#        [ 13.35192552],
#        [-44.39433775],
#        [ -2.36122692],
#        [-10.03469777],
#        [ 10.27833038],
#        [ 30.84031082],
#        [ 23.3723328 ],
#        [ 20.38502317],
#        [-19.5754251 ],
#        [ 23.13291539],
#        [ 29.38289173],
#        [ 38.85425766],
#        [-20.41240441],
#        [-12.75588011],
#        [-23.85205547],
#        [ 11.65094979],
#        [ 35.27840802],
#        [ 17.99653881],
#        [ -4.5669519 ],
#        [-26.06391348],
#        [ 10.66362793],
#        [ -3.53318065],
#        [ -3.89576147],
#        [ 50.37665946],
#        [-31.38559572],
#        [ 13.41850651],
#        [-55.84043082],
#        [-23.5563524 ],
#        [  1.24786248],
#        [ -3.03974883],
#        [ -6.3356992 ],
#        [ 13.36820716],
#        [  6.53652574],
#        [ 17.49032702],
#        [ 18.68113514],
#        [-12.59436912],
#        [ 35.13686903],
#        [ 12.51920277],
#        [-29.68206155],
#        [ 35.28169442],
#        [-11.94015042],
#        [ 12.01804574],
#        [  0.5234    ],
#        [-20.59219583],
#        [ 20.82777409],
#        [-11.12365148],
#        [-29.57390869],
#        [ 36.64339041],
#        [ 12.95277616],
#        [-17.05274472],
#        [ 11.36528156],
#        [  7.41031867],
#        [ 54.85561916],
#        [ 14.57711155],
#        [-12.99346867],
#        [-56.43125551],
#        [-11.05664436],
#        [ 49.17644353],
#        [-33.47631306],
#        [-11.55247693],
#        [-23.37322285]])
